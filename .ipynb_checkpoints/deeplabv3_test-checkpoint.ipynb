# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras.backend as K
from model import Deeplabv3
from keras.models import Model
from keras.layers import Conv2D, Lambda, Activation
from keras.models import load_model
from keras.optimizers import Adam
# %matplotlib inline


K.clear_session()
# model = load_model("C:/Users/Administrator/Desktop/deeplab/face_model_transfered.h5")
classes = 2
base_model = Deeplabv3(backbone="xception")
transfered_model = Model(inputs=base_model.input, outputs=base_model.get_layer("decoder_conv1_pointwise_activation").output)
# for layer in transfered_model.layers:
#     layer.trainable = False

x = Conv2D(classes, (1, 1), padding="same", name="logits_semantic")(transfered_model.output)
# size = tf.int_shape(transfered_model.input)
size_before4 = K.int_shape(transfered_model.input)
# x = Lambda(lambda xx: tf.image.resize(xx, size_before4[1:3], method="bilinear", align_corners=True))(x)
x = Lambda(lambda xx: tf.image.resize(xx, size_before4[1:3], method="bilinear", align_corners=True))(x)
x = Activation("sigmoid")(x)
model = Model(inputs=transfered_model.input, outputs=x)
optimizer = Adam(lr=0.001)
model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# entry_flow_conv1_1 (Conv2D)     (None, 256, 256, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_1_BN (BatchNor (None, 256, 256, 32) 128         entry_flow_conv1_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           entry_flow_conv1_1_BN[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_2 (Conv2D)     (None, 256, 256, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_2_BN (BatchNor (None, 256, 256, 64) 256         entry_flow_conv1_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 64) 0           entry_flow_conv1_2_BN[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 64) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 64) 576         activation_3[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 64) 256         entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 8192        entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 512         entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256, 256, 128 0           entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 1152        activation_4[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 512         entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 16384       entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 512         entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 258, 258, 128 0           entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 258, 258, 128 0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 1152        activation_5[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 512         entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 256, 256, 64) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 16384       entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block1_shortcut (Con (None, 128, 128, 128 8192        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 512         entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block1_shortcut_BN ( (None, 128, 128, 128 512         entry_flow_block1_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 128 0           entry_flow_block1_separable_conv3
#                                                                  entry_flow_block1_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 128, 128 0           add_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 128 1152        activation_6[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 128 512         entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 32768       entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 1024        entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 256 0           entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 2304        activation_7[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 1024        entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 65536       entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 1024        entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 130, 130, 256 0           entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 130, 130, 256 0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  2304        activation_8[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  1024        entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 128, 128, 128 0           add_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  65536       entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block2_shortcut (Con (None, 64, 64, 256)  32768       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  1024        entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block2_shortcut_BN ( (None, 64, 64, 256)  1024        entry_flow_block2_shortcut[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 256)  0           entry_flow_block2_separable_conv3
#                                                                  entry_flow_block2_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 256)  2304        activation_9[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 256)  1024        entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  186368      entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  2912        entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 728)  0           entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  6552        activation_10[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  2912        entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  529984      entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  2912        entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 66, 66, 728)  0           entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 66, 66, 728)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  6552        activation_11[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  2912        entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 64, 64, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  529984      entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block3_shortcut (Con (None, 32, 32, 728)  186368      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  2912        entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block3_shortcut_BN ( (None, 32, 32, 728)  2912        entry_flow_block3_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 728)  0           entry_flow_block3_separable_conv3
#                                                                  entry_flow_block3_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  6552        activation_12[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  6552        activation_13[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  6552        activation_14[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_1_separable_conv
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  6552        activation_15[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  6552        activation_16[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  6552        activation_17[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_2_separable_conv
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  6552        activation_18[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  6552        activation_19[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  6552        activation_20[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_3_separable_conv
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  6552        activation_21[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  6552        activation_22[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  6552        activation_23[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_4_separable_conv
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  6552        activation_24[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  6552        activation_25[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  6552        activation_26[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_5_separable_conv
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  6552        activation_27[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  6552        activation_28[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  6552        activation_29[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_6_separable_conv
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  6552        activation_30[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  6552        activation_31[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  6552        activation_32[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 728)  0           middle_flow_unit_7_separable_conv
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  6552        activation_33[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  6552        activation_34[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  6552        activation_35[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 728)  0           middle_flow_unit_8_separable_conv
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 32, 32, 728)  0           add_11[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  6552        activation_36[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  6552        activation_37[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 32, 32, 1024) 1048576     exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_shortcut (Conv (None, 32, 32, 1024) 745472      add_19[0][0]
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 32, 32, 1024) 4096        exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_shortcut_BN (B (None, 32, 32, 1024) 4096        exit_flow_block1_shortcut[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 1024) 0           exit_flow_block1_separable_conv3_
#                                                                  exit_flow_block1_shortcut_BN[0][0
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1024) 9216        add_20[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1024) 4096        exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 1024) 0           exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 1572864     activation_63[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 13824       exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 2359296     activation_64[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 13824       exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 2048) 3145728     activation_65[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 2048) 8192        exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 2048) 0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 2048)      0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise (DepthwiseConv2 (None, 32, 32, 2048) 18432       exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# aspp2_depthwise (DepthwiseConv2 (None, 32, 32, 2048) 18432       exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# aspp3_depthwise (DepthwiseConv2 (None, 32, 32, 2048) 18432       exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1, 1, 2048)   0           lambda_1[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise_BN (BatchNormal (None, 32, 32, 2048) 8192        aspp1_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp2_depthwise_BN (BatchNormal (None, 32, 32, 2048) 8192        aspp2_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp3_depthwise_BN (BatchNormal (None, 32, 32, 2048) 8192        aspp3_depthwise[0][0]
# __________________________________________________________________________________________________
# image_pooling (Conv2D)          (None, 1, 1, 256)    524288      lambda_2[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 32, 32, 2048) 0           aspp1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 32, 32, 2048) 0           aspp2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 32, 32, 2048) 0           aspp3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# image_pooling_BN (BatchNormaliz (None, 1, 1, 256)    1024        image_pooling[0][0]
# __________________________________________________________________________________________________
# aspp0 (Conv2D)                  (None, 32, 32, 256)  524288      exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# aspp1_pointwise (Conv2D)        (None, 32, 32, 256)  524288      activation_67[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise (Conv2D)        (None, 32, 32, 256)  524288      activation_68[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise (Conv2D)        (None, 32, 32, 256)  524288      activation_69[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 1, 1, 256)    0           image_pooling_BN[0][0]
# __________________________________________________________________________________________________
# aspp0_BN (BatchNormalization)   (None, 32, 32, 256)  1024        aspp0[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise_BN (BatchNormal (None, 32, 32, 256)  1024        aspp1_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise_BN (BatchNormal (None, 32, 32, 256)  1024        aspp2_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise_BN (BatchNormal (None, 32, 32, 256)  1024        aspp3_pointwise[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32, 32, 256)  0           activation_66[0][0]
# __________________________________________________________________________________________________
# aspp0_activation (Activation)   (None, 32, 32, 256)  0           aspp0_BN[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise_activation (Act (None, 32, 32, 256)  0           aspp1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise_activation (Act (None, 32, 32, 256)  0           aspp2_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise_activation (Act (None, 32, 32, 256)  0           aspp3_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 1280) 0           lambda_3[0][0]
#                                                                  aspp0_activation[0][0]
#                                                                  aspp1_pointwise_activation[0][0]
#                                                                  aspp2_pointwise_activation[0][0]
#                                                                  aspp3_pointwise_activation[0][0]
# __________________________________________________________________________________________________
# concat_projection (Conv2D)      (None, 32, 32, 256)  327680      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concat_projection_BN (BatchNorm (None, 32, 32, 256)  1024        concat_projection[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 32, 32, 256)  0           concat_projection_BN[0][0]
# __________________________________________________________________________________________________
# feature_projection0 (Conv2D)    (None, 128, 128, 48) 12288       entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 256)  0           activation_70[0][0]
# __________________________________________________________________________________________________
# feature_projection0_BN (BatchNo (None, 128, 128, 48) 192         feature_projection0[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128, 128, 256 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 128, 128, 48) 0           feature_projection0_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 304 0           lambda_4[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_depthwise (Depthw (None, 128, 128, 304 2736        concatenate_2[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_depthwise_BN (Bat (None, 128, 128, 304 1216        decoder_conv0_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 128, 128, 304 0           decoder_conv0_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise (Conv2D (None, 128, 128, 256 77824       activation_72[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise_BN (Bat (None, 128, 128, 256 1024        decoder_conv0_pointwise[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise_activat (None, 128, 128, 256 0           decoder_conv0_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_depthwise (Depthw (None, 128, 128, 256 2304        decoder_conv0_pointwise_activatio
# __________________________________________________________________________________________________
# decoder_conv1_depthwise_BN (Bat (None, 128, 128, 256 1024        decoder_conv1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 128, 128, 256 0           decoder_conv1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise (Conv2D (None, 128, 128, 256 65536       activation_73[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise_BN (Bat (None, 128, 128, 256 1024        decoder_conv1_pointwise[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise_activat (None, 128, 128, 256 0           decoder_conv1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# logits_semantic (Conv2D)        (None, 128, 128, 2)  514         decoder_conv1_pointwise_activatio
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 512, 512, 2)  0           logits_semantic[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 512, 512, 2)  0           lambda_6[0][0]
# ==================================================================================================
# Total params: 41,253,330
# Trainable params: 41,050,530
# Non-trainable params: 202,800
# __________________________________________________________________________________________________

# %%
model.load_weights("C:/Users/Administrator/Desktop/deeplab/face_model_transfered_weights.h5")

# %%
# model.save("C:/Users/Administrator/Desktop/deeplab/face_model_transfered_1.h5

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# entry_flow_conv1_1 (Conv2D)     (None, 256, 256, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_1_BN (BatchNor (None, 256, 256, 32) 128         entry_flow_conv1_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           entry_flow_conv1_1_BN[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_2 (Conv2D)     (None, 256, 256, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_2_BN (BatchNor (None, 256, 256, 64) 256         entry_flow_conv1_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 64) 0           entry_flow_conv1_2_BN[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 64) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 64) 576         activation_3[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 64) 256         entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 8192        entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 512         entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256, 256, 128 0           entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 1152        activation_4[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 512         entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 16384       entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 512         entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 258, 258, 128 0           entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 258, 258, 128 0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 1152        activation_5[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 512         entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 256, 256, 64) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 16384       entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block1_shortcut (Con (None, 128, 128, 128 8192        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 512         entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block1_shortcut_BN ( (None, 128, 128, 128 512         entry_flow_block1_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 128 0           entry_flow_block1_separable_conv3
#                                                                  entry_flow_block1_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 128, 128 0           add_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 128 1152        activation_6[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 128 512         entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 32768       entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 1024        entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 256 0           entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 2304        activation_7[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 1024        entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 65536       entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 1024        entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 130, 130, 256 0           entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 130, 130, 256 0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  2304        activation_8[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  1024        entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 128, 128, 128 0           add_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  65536       entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block2_shortcut (Con (None, 64, 64, 256)  32768       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  1024        entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block2_shortcut_BN ( (None, 64, 64, 256)  1024        entry_flow_block2_shortcut[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 256)  0           entry_flow_block2_separable_conv3
#                                                                  entry_flow_block2_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 256)  2304        activation_9[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 256)  1024        entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  186368      entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  2912        entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 728)  0           entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  6552        activation_10[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  2912        entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  529984      entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  2912        entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 66, 66, 728)  0           entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 66, 66, 728)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  6552        activation_11[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  2912        entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 64, 64, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  529984      entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block3_shortcut (Con (None, 32, 32, 728)  186368      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  2912        entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block3_shortcut_BN ( (None, 32, 32, 728)  2912        entry_flow_block3_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 728)  0           entry_flow_block3_separable_conv3
#                                                                  entry_flow_block3_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  6552        activation_12[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  6552        activation_13[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  6552        activation_14[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_1_separable_conv
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  6552        activation_15[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  6552        activation_16[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  6552        activation_17[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_2_separable_conv
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  6552        activation_18[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  6552        activation_19[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  6552        activation_20[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_3_separable_conv
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  6552        activation_21[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  6552        activation_22[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  6552        activation_23[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_4_separable_conv
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  6552        activation_24[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  6552        activation_25[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  6552        activation_26[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_5_separable_conv
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  6552        activation_27[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  6552        activation_28[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  6552        activation_29[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_6_separable_conv
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  6552        activation_30[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  6552        activation_31[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  6552        activation_32[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 728)  0           middle_flow_unit_7_separable_conv
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  6552        activation_33[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  6552        activation_34[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  6552        activation_35[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 728)  0           middle_flow_unit_8_separable_conv
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 32, 32, 728)  0           add_11[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  6552        activation_36[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  6552        activation_37[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  6552        activation_38[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 32, 728)  0           middle_flow_unit_9_separable_conv
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 728)  0           add_12[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  6552        activation_39[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  6552        activation_40[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  6552        activation_41[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 32, 728)  0           middle_flow_unit_10_separable_con
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 728)  0           add_13[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 32, 32, 728)  6552        activation_42[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 32, 32, 728)  529984      middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 32, 32, 728)  6552        activation_43[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 32, 32, 1024) 1048576     exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_shortcut (Conv (None, 32, 32, 1024) 745472      add_19[0][0]
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 32, 32, 1024) 4096        exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_shortcut_BN (B (None, 32, 32, 1024) 4096        exit_flow_block1_shortcut[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 1024) 0           exit_flow_block1_separable_conv3_
#                                                                  exit_flow_block1_shortcut_BN[0][0
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1024) 9216        add_20[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1024) 4096        exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 1024) 0           exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 1572864     activation_63[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 13824       exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 2359296     activation_64[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 13824       exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 2048) 3145728     activation_65[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 2048) 8192        exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 2048) 0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 2048)      0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise (DepthwiseConv2 (None, 32, 32, 2048) 18432       exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# aspp2_depthwise (DepthwiseConv2 (None, 32, 32, 2048) 18432       exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# aspp3_depthwise (DepthwiseConv2 (None, 32, 32, 2048) 18432       exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1, 1, 2048)   0           lambda_1[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise_BN (BatchNormal (None, 32, 32, 2048) 8192        aspp1_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp2_depthwise_BN (BatchNormal (None, 32, 32, 2048) 8192        aspp2_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp3_depthwise_BN (BatchNormal (None, 32, 32, 2048) 8192        aspp3_depthwise[0][0]
# __________________________________________________________________________________________________
# image_pooling (Conv2D)          (None, 1, 1, 256)    524288      lambda_2[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 32, 32, 2048) 0           aspp1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 32, 32, 2048) 0           aspp2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 32, 32, 2048) 0           aspp3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# image_pooling_BN (BatchNormaliz (None, 1, 1, 256)    1024        image_pooling[0][0]
# __________________________________________________________________________________________________
# aspp0 (Conv2D)                  (None, 32, 32, 256)  524288      exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# aspp1_pointwise (Conv2D)        (None, 32, 32, 256)  524288      activation_67[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise (Conv2D)        (None, 32, 32, 256)  524288      activation_68[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise (Conv2D)        (None, 32, 32, 256)  524288      activation_69[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 1, 1, 256)    0           image_pooling_BN[0][0]
# __________________________________________________________________________________________________
# aspp0_BN (BatchNormalization)   (None, 32, 32, 256)  1024        aspp0[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise_BN (BatchNormal (None, 32, 32, 256)  1024        aspp1_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise_BN (BatchNormal (None, 32, 32, 256)  1024        aspp2_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise_BN (BatchNormal (None, 32, 32, 256)  1024        aspp3_pointwise[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32, 32, 256)  0           activation_66[0][0]
# __________________________________________________________________________________________________
# aspp0_activation (Activation)   (None, 32, 32, 256)  0           aspp0_BN[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise_activation (Act (None, 32, 32, 256)  0           aspp1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise_activation (Act (None, 32, 32, 256)  0           aspp2_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise_activation (Act (None, 32, 32, 256)  0           aspp3_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 1280) 0           lambda_3[0][0]
#                                                                  aspp0_activation[0][0]
#                                                                  aspp1_pointwise_activation[0][0]
#                                                                  aspp2_pointwise_activation[0][0]
#                                                                  aspp3_pointwise_activation[0][0]
# __________________________________________________________________________________________________
# concat_projection (Conv2D)      (None, 32, 32, 256)  327680      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concat_projection_BN (BatchNorm (None, 32, 32, 256)  1024        concat_projection[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 32, 32, 256)  0           concat_projection_BN[0][0]
# __________________________________________________________________________________________________
# feature_projection0 (Conv2D)    (None, 128, 128, 48) 12288       entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 256)  0           activation_70[0][0]
# __________________________________________________________________________________________________
# feature_projection0_BN (BatchNo (None, 128, 128, 48) 192         feature_projection0[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128, 128, 256 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 128, 128, 48) 0           feature_projection0_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 304 0           lambda_4[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_depthwise (Depthw (None, 128, 128, 304 2736        concatenate_2[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_depthwise_BN (Bat (None, 128, 128, 304 1216        decoder_conv0_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 128, 128, 304 0           decoder_conv0_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise (Conv2D (None, 128, 128, 256 77824       activation_72[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise_BN (Bat (None, 128, 128, 256 1024        decoder_conv0_pointwise[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise_activat (None, 128, 128, 256 0           decoder_conv0_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_depthwise (Depthw (None, 128, 128, 256 2304        decoder_conv0_pointwise_activatio
# __________________________________________________________________________________________________
# decoder_conv1_depthwise_BN (Bat (None, 128, 128, 256 1024        decoder_conv1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 128, 128, 256 0           decoder_conv1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise (Conv2D (None, 128, 128, 256 65536       activation_73[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise_BN (Bat (None, 128, 128, 256 1024        decoder_conv1_pointwise[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise_activat (None, 128, 128, 256 0           decoder_conv1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# logits_semantic (Conv2D)        (None, 128, 128, 2)  514         decoder_conv1_pointwise_activatio
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 512, 512, 2)  0           logits_semantic[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 512, 512, 2)  0           lambda_6[0][0]
# ==================================================================================================
# Total params: 41,253,330
# Trainable params: 41,050,530
# Non-trainable params: 202,800
# __________________________________________________________________________________________________

# %%
img_to_test = cv2.imread("C:/Users/Administrator/Desktop/deeplab/img_to_test.jpg")
# cv2.imshow('img_to_test', img_to_test)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img_to_test)

# %%
img_to_test = cv2.resize(img_to_test, (512, 512), interpolation=cv2.INTER_CUBIC)

# %%
img_to_test = img_to_test / 127.5 - 1

# %%
img_to_test = np.expand_dims(img_to_test, axis=0)

# %%
res = model.predict(img_to_test)

# %%
res.shape
# Out:
# (1, 512, 512, 2)

# %%
res[0, :, :, 0].shape
# Out:
# (512, 512)

# %%
np.where(res[0, :, :, 0] > 0.5)
# Out:
# (array([  0,   0,   0, ..., 511, 511, 511], dtype=int64),
#  array([  0,   1,   2, ..., 509, 510, 511], dtype=int64))

# %%
np.where(res[0, :, :, 1] > 0.5)
# Out:
# (array([  0,   0,   0, ..., 511, 511, 511], dtype=int64),
#  array([ 4,  5,  6, ..., 20, 21, 22], dtype=int64))

# %%
mask = np.uint8(res[0, :, :, 0] > 0.5)

# %%
mask.shape
# Out:
# (512, 512)

# %%
img_to_test = cv2.imread("C:/Users/Administrator/Desktop/deeplab/img_to_test.jpg")
img_to_test = cv2.resize(img_to_test, (512, 512), interpolation=cv2.INTER_CUBIC)
img_to_test.shape
# Out:
# (512, 512, 3)

# %%
mask = np.uint8(res[0, :, :, 0] > 0.8)

inversed_mask = 1 - mask

bg = np.ones((512, 512, 3), dtype="uint8") * 255
masked_img = cv2.bitwise_and(img_to_test, img_to_test, mask=mask)
masked_bg = cv2.bitwise_and(bg, bg, mask=inversed_mask)
composed_img = cv2.add(masked_img, masked_bg) 
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(composed_img)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras.backend as K
from model import Deeplabv3
from keras.models import Model
from keras.layers import Conv2D, Lambda, Activation
from keras.models import load_model
from keras.optimizers import Adam
# %matplotlib inline


K.clear_session()

model = Deeplabv3(classes=2, backbone="xception", activation="sigmoid")
model.load_weights("C:/Users/Administrator/Desktop/deeplab/face_model_weights.h5")
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# entry_flow_conv1_1 (Conv2D)     (None, 256, 256, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_1_BN (BatchNor (None, 256, 256, 32) 128         entry_flow_conv1_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           entry_flow_conv1_1_BN[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_2 (Conv2D)     (None, 256, 256, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_2_BN (BatchNor (None, 256, 256, 64) 256         entry_flow_conv1_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 64) 0           entry_flow_conv1_2_BN[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 64) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 64) 576         activation_3[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 64) 256         entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 8192        entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 512         entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256, 256, 128 0           entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 1152        activation_4[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 512         entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 16384       entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 256, 256, 128 512         entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 258, 258, 128 0           entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 258, 258, 128 0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 1152        activation_5[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 512         entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 256, 256, 64) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 16384       entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block1_shortcut (Con (None, 128, 128, 128 8192        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 512         entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block1_shortcut_BN ( (None, 128, 128, 128 512         entry_flow_block1_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 128 0           entry_flow_block1_separable_conv3
#                                                                  entry_flow_block1_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 128, 128 0           add_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 128 1152        activation_6[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 128 512         entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 32768       entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 1024        entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 256 0           entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 2304        activation_7[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 1024        entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 65536       entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 128, 128, 256 1024        entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 130, 130, 256 0           entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 130, 130, 256 0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  2304        activation_8[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  1024        entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 128, 128, 128 0           add_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  65536       entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block2_shortcut (Con (None, 64, 64, 256)  32768       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  1024        entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block2_shortcut_BN ( (None, 64, 64, 256)  1024        entry_flow_block2_shortcut[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 256)  0           entry_flow_block2_separable_conv3
#                                                                  entry_flow_block2_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 256)  2304        activation_9[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 256)  1024        entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  186368      entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  2912        entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 728)  0           entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  6552        activation_10[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  2912        entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  529984      entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 64, 64, 728)  2912        entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 66, 66, 728)  0           entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 66, 66, 728)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  6552        activation_11[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  2912        entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 64, 64, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  529984      entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block3_shortcut (Con (None, 32, 32, 728)  186368      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  2912        entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block3_shortcut_BN ( (None, 32, 32, 728)  2912        entry_flow_block3_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 728)  0           entry_flow_block3_separable_conv3
#                                                                  entry_flow_block3_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  6552        activation_12[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  6552        activation_13[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  6552        activation_14[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_1_separable_conv
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  6552        activation_15[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  6552        activation_16[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  6552        activation_17[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_2_separable_conv
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  6552        activation_18[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  6552        activation_19[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  6552        activation_20[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_3_separable_conv
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  6552        activation_21[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  6552        activation_22[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  6552        activation_23[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_4_separable_conv
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  6552        activation_24[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  6552        activation_25[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  6552        activation_26[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_5_separable_conv
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  6552        activation_27[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  6552        activation_28[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  6552        activation_29[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 728)  0           middle_flow_unit_6_separable_conv
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  6552        activation_30[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  6552        activation_31[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  6552        activation_32[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 728)  0           middle_flow_unit_7_separable_conv
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  6552        activation_33[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  6552        activation_34[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  6552        activation_35[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 728)  0           middle_flow_unit_8_separable_conv
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 32, 32, 728)  0           add_11[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  6552        activation_36[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  6552        activation_37[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  6552        activation_38[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 32, 32, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 32, 728)  0           middle_flow_unit_9_separable_conv
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 728)  0           add_12[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  6552        activation_39[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  6552        activation_40[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  6552        activation_41[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 32, 728)  0           middle_flow_unit_10_separable_con
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 728)  0           add_13[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 32, 32, 728)  6552        activation_42[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 32, 32, 728)  529984      middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 32, 32, 728)  2912        middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 728)  0           middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 32, 32, 728)  6552        activation_43[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 32, 32, 1024) 1048576     exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_shortcut (Conv (None, 32, 32, 1024) 745472      add_19[0][0]
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 32, 32, 1024) 4096        exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_shortcut_BN (B (None, 32, 32, 1024) 4096        exit_flow_block1_shortcut[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 1024) 0           exit_flow_block1_separable_conv3_
#                                                                  exit_flow_block1_shortcut_BN[0][0
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1024) 9216        add_20[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1024) 4096        exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 1024) 0           exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 1572864     activation_63[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 13824       exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 2359296     activation_64[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 13824       exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 1536) 6144        exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 1536) 0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 2048) 3145728     activation_65[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 2048) 8192        exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 32, 32, 2048) 0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 2048)      0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise (DepthwiseConv2 (None, 32, 32, 2048) 18432       exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# aspp2_depthwise (DepthwiseConv2 (None, 32, 32, 2048) 18432       exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# aspp3_depthwise (DepthwiseConv2 (None, 32, 32, 2048) 18432       exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1, 1, 2048)   0           lambda_1[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise_BN (BatchNormal (None, 32, 32, 2048) 8192        aspp1_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp2_depthwise_BN (BatchNormal (None, 32, 32, 2048) 8192        aspp2_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp3_depthwise_BN (BatchNormal (None, 32, 32, 2048) 8192        aspp3_depthwise[0][0]
# __________________________________________________________________________________________________
# image_pooling (Conv2D)          (None, 1, 1, 256)    524288      lambda_2[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 32, 32, 2048) 0           aspp1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 32, 32, 2048) 0           aspp2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 32, 32, 2048) 0           aspp3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# image_pooling_BN (BatchNormaliz (None, 1, 1, 256)    1024        image_pooling[0][0]
# __________________________________________________________________________________________________
# aspp0 (Conv2D)                  (None, 32, 32, 256)  524288      exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# aspp1_pointwise (Conv2D)        (None, 32, 32, 256)  524288      activation_67[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise (Conv2D)        (None, 32, 32, 256)  524288      activation_68[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise (Conv2D)        (None, 32, 32, 256)  524288      activation_69[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 1, 1, 256)    0           image_pooling_BN[0][0]
# __________________________________________________________________________________________________
# aspp0_BN (BatchNormalization)   (None, 32, 32, 256)  1024        aspp0[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise_BN (BatchNormal (None, 32, 32, 256)  1024        aspp1_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise_BN (BatchNormal (None, 32, 32, 256)  1024        aspp2_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise_BN (BatchNormal (None, 32, 32, 256)  1024        aspp3_pointwise[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32, 32, 256)  0           activation_66[0][0]
# __________________________________________________________________________________________________
# aspp0_activation (Activation)   (None, 32, 32, 256)  0           aspp0_BN[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise_activation (Act (None, 32, 32, 256)  0           aspp1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise_activation (Act (None, 32, 32, 256)  0           aspp2_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise_activation (Act (None, 32, 32, 256)  0           aspp3_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 1280) 0           lambda_3[0][0]
#                                                                  aspp0_activation[0][0]
#                                                                  aspp1_pointwise_activation[0][0]
#                                                                  aspp2_pointwise_activation[0][0]
#                                                                  aspp3_pointwise_activation[0][0]
# __________________________________________________________________________________________________
# concat_projection (Conv2D)      (None, 32, 32, 256)  327680      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concat_projection_BN (BatchNorm (None, 32, 32, 256)  1024        concat_projection[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 32, 32, 256)  0           concat_projection_BN[0][0]
# __________________________________________________________________________________________________
# feature_projection0 (Conv2D)    (None, 128, 128, 48) 12288       entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 256)  0           activation_70[0][0]
# __________________________________________________________________________________________________
# feature_projection0_BN (BatchNo (None, 128, 128, 48) 192         feature_projection0[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128, 128, 256 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 128, 128, 48) 0           feature_projection0_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 304 0           lambda_4[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_depthwise (Depthw (None, 128, 128, 304 2736        concatenate_2[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_depthwise_BN (Bat (None, 128, 128, 304 1216        decoder_conv0_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 128, 128, 304 0           decoder_conv0_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise (Conv2D (None, 128, 128, 256 77824       activation_72[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise_BN (Bat (None, 128, 128, 256 1024        decoder_conv0_pointwise[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise_activat (None, 128, 128, 256 0           decoder_conv0_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_depthwise (Depthw (None, 128, 128, 256 2304        decoder_conv0_pointwise_activatio
# __________________________________________________________________________________________________
# decoder_conv1_depthwise_BN (Bat (None, 128, 128, 256 1024        decoder_conv1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 128, 128, 256 0           decoder_conv1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise (Conv2D (None, 128, 128, 256 65536       activation_73[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise_BN (Bat (None, 128, 128, 256 1024        decoder_conv1_pointwise[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise_activat (None, 128, 128, 256 0           decoder_conv1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# custom_logits_semantic (Conv2D) (None, 128, 128, 2)  514         decoder_conv1_pointwise_activatio
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 512, 512, 2)  0           custom_logits_semantic[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 512, 512, 2)  0           lambda_5[0][0]
# ==================================================================================================
# Total params: 41,253,330
# Trainable params: 41,050,530
# Non-trainable params: 202,800
# __________________________________________________________________________________________________

# %%
img_to_test = cv2.imread("C:/Users/Administrator/Desktop/deeplab/img_to_test.jpg")
img_to_test = cv2.resize(img_to_test, (512, 512), interpolation=cv2.INTER_CUBIC)
plt.imshow(img_to_test)

# %%
img_to_test_n = img_to_test / 127.5 - 1
img_to_test_n = np.expand_dims(img_to_test_n, axis=0)
res = model.predict(img_to_test_n)

# %%
mask = np.uint8(res[0, :, :, 0] > 0.92)
inversed_mask = 1 - mask
# inversed_mask = np.uint8(res[0, :, :, 1] > 0.90)
bg = np.ones((512, 512, 3), dtype="uint8") * 255
masked_img = cv2.bitwise_and(img_to_test, img_to_test, mask=mask)
masked_bg = cv2.bitwise_and(bg, bg, mask=inversed_mask)
composed_img = cv2.add(masked_img, masked_bg) 
plt.imshow(composed_img)
